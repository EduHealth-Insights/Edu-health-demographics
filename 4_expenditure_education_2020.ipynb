# %%
import pandas as pd
import numpy as np
import python_functions_sp as pfsp
import sql_functions_sp as sfsp
import warnings
warnings.filterwarnings("ignore")
import sqlalchemy
import psycopg2
import sql_functions_sp as sf

# %% [markdown]
# # Import

# %%
# overview = pd.read_excel('data/statistic_id238733_per-student-expenditure-on-educational-institutions-in-oecd-countries-2020.xlsx')
expenditure_education_2020 = pd.read_excel('data/statistic_id238733_per-student-expenditure-on-educational-institutions-in-oecd-countries-2020.xlsx', sheet_name='Data', header=4)

# %%
expenditure_education_2020 = expenditure_education_2020.drop('Unnamed: 0', axis=1)

# %% [markdown]
# # Column names

# %%
pfsp.columns_lower_snake_case_4(expenditure_education_2020)
# Out:
#          unnamed:_1  primary_education  secondary_education
# 0        Luxembourg              22990                26617  \
# 1            Norway              15631                17229
# 2           Iceland              15206                15242
# 3     United States              14321                16018
# 4           Denmark              14273                14125
# 5           Austria              14029                17478
# 6            Sweden              13997                13902
# 7             Korea              13278                17038
# 8           Belgium              12813                16576
# 9         Australia              12673                15437
# 10   United Kingdom              12513                13695
# 11            Italy              12008                10659
# 12           Poland              11872                 8485
# 13          Germany              11587                15614
# 14           Canada              11533                14520
# 15          Finland              11212                12849
# 16      Netherlands              11188                15848
# 17         Slovenia              10714                10450
# 18     OECD average              10658                11942
# 19          Estonia              10309                 8522
# 20           Israel              10182                 9562
# 21            Japan              10057                12047
# 22           France               9673                13874
# 23          Ireland               9589                11379
# 24         Portugal               9340                11358
# 25            Spain               9077                11159
# 26  Slovak Republic               8853                 8546
# 27   Czech Republic               8466                12579
# 28      New Zealand               8438                10223
# 29        Lithuania               8173                 8426
# 30          Hungary               7928                 7772
# 31           Greece               7467                 6901
# 32           Latvia               7142                 8302
# 33            Chile               5917                 5868
# 34         Colombia               4364                 4341
# 35           Turkey               4108                 4603
# 36           Mexico               2750                 2770
#
#     tertiary_education
# 0                53421
# 1                24374
# 2                16128
# 3                36172
# 4                23432
# 5                21753
# 6                26215
# 7                12225
# 8                22555
# 9                22204
# 10               29534
# 11               12663
# 12               14488
# 13               20760
# 14               24363
# 15               19583
# 16               21642
# 17               17795
# 18               18105
# 19               17930
# 20               12314
# 21               19676
# 22               18880
# 23               17400
# 24               12104
# 25               14361
# 26               14637
# 27               16237
# 28               19567
# 29               13629
# 30               12098
# 31                4300
# 32               13043
# 33               10458
# 34                4981
# 35                9288
# 36                5887

# %%
expenditure_education_2020.rename(columns={'unnamed:_1': 'country'}, inplace=True)

# %% [markdown]
# # Assign continent to country

# %% [markdown]
# Assigning the continent to the countries in a new created column:

# %%
expenditure_education_2020['continent'] = expenditure_education_2020['country'].apply(pfsp.assign_continent)

# %% [markdown]
# Assigning the four parts of europe to the countries in another new created column:

# %%
expenditure_education_2020['continent_region'] = expenditure_education_2020['country'].apply(pfsp.assign_europe_region)

# %% [markdown]
# Changing the order of the columns:

# %%
expenditure_education_2020.columns
# Out:
# Index(['country', 'primary_education', 'secondary_education',
#        'tertiary_education', 'continent', 'continent_region'],
#       dtype='object')

# %%
columns = ['country', 'continent', 'continent_region', 'primary_education', 'secondary_education', 'tertiary_education']

expenditure_education_2020 = expenditure_education_2020[columns]

# %% [markdown]
# Check if some countries couldn't be assigned to a continent:

# %%
expenditure_education_2020[expenditure_education_2020['continent'] == 'Other']['country'].unique()
# Out:
# array(['OECD average'], dtype=object)

# %%
expenditure_education_2020[expenditure_education_2020['continent_region'] == 'Other']['country'].unique()
# Out:
# array(['OECD average'], dtype=object)

# %% [markdown]
# Check if the new created columns match:

# %%
pfsp.check_values(expenditure_education_2020)
# Out:
# All values match.

# %% [markdown]
# ---

# %%
expenditure_education_2020
# Out:
#             country      continent continent_region  primary_education
# 0        Luxembourg         Europe      West Europe              22990  \
# 1            Norway         Europe     North Europe              15631
# 2           Iceland         Europe     North Europe              15206
# 3     United States  North America    North America              14321
# 4           Denmark         Europe     North Europe              14273
# 5           Austria         Europe      West Europe              14029
# 6            Sweden         Europe     North Europe              13997
# 7             Korea        Pacific          Pacific              13278
# 8           Belgium         Europe      West Europe              12813
# 9         Australia        Pacific          Pacific              12673
# 10   United Kingdom         Europe     North Europe              12513
# 11            Italy         Europe     South Europe              12008
# 12           Poland         Europe      East Europe              11872
# 13          Germany         Europe      West Europe              11587
# 14           Canada  North America    North America              11533
# 15          Finland         Europe     North Europe              11212
# 16      Netherlands         Europe      West Europe              11188
# 17         Slovenia         Europe     South Europe              10714
# 18     OECD average          Other            Other              10658
# 19          Estonia         Europe     North Europe              10309
# 20           Israel           Asia             Asia              10182
# 21            Japan        Pacific          Pacific              10057
# 22           France         Europe      West Europe               9673
# 23          Ireland         Europe     North Europe               9589
# 24         Portugal         Europe     South Europe               9340
# 25            Spain         Europe     South Europe               9077
# 26  Slovak Republic         Europe      East Europe               8853
# 27   Czech Republic         Europe      East Europe               8466
# 28      New Zealand        Pacific          Pacific               8438
# 29        Lithuania         Europe     North Europe               8173
# 30          Hungary         Europe      East Europe               7928
# 31           Greece         Europe     South Europe               7467
# 32           Latvia         Europe     North Europe               7142
# 33            Chile  South America    South America               5917
# 34         Colombia  South America    South America               4364
# 35           Turkey           Asia             Asia               4108
# 36           Mexico  South America    South America               2750
#
#     secondary_education  tertiary_education
# 0                 26617               53421
# 1                 17229               24374
# 2                 15242               16128
# 3                 16018               36172
# 4                 14125               23432
# 5                 17478               21753
# 6                 13902               26215
# 7                 17038               12225
# 8                 16576               22555
# 9                 15437               22204
# 10                13695               29534
# 11                10659               12663
# 12                 8485               14488
# 13                15614               20760
# 14                14520               24363
# 15                12849               19583
# 16                15848               21642
# 17                10450               17795
# 18                11942               18105
# 19                 8522               17930
# 20                 9562               12314
# 21                12047               19676
# 22                13874               18880
# 23                11379               17400
# 24                11358               12104
# 25                11159               14361
# 26                 8546               14637
# 27                12579               16237
# 28                10223               19567
# 29                 8426               13629
# 30                 7772               12098
# 31                 6901                4300
# 32                 8302               13043
# 33                 5868               10458
# 34                 4341                4981
# 35                 4603                9288
# 36                 2770                5887

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Writing the table into the database

# %%
sfsp.push_to_cloud(expenditure_education_2020, 'expenditure_education_2020')
# Out:
# The expenditure_education_2020 table was imported successfully.

# %% [markdown]
# # Store the DataFrames

# %%
# %store expenditure_education_2020
# Out:
# Stored 'expenditure_education_2020' (DataFrame)

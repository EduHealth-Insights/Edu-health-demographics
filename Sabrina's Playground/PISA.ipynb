# %%
import pandas as pd

# %%
rescaled_indices_df = pd.read_csv('PISA/escs_trend/escs_trend.csv')

# %%
rescaled_indices_df.head(20)
# Out:
#     cycnt  cycle  cnt  schoolid  studentid  oecd  escs_trend  hisei_trend  \
# 0   05ARE      5  ARE         1          1     0      0.3226    82.410004
# 1   05ARE      5  ARE         1          2     0      0.0598          NaN
# 2   05ARE      5  ARE         1          3     0     -0.8984    51.500000
# 3   05ARE      5  ARE         1          4     0      0.4869    81.400002
# 4   05ARE      5  ARE         1          5     0     -0.5238    63.029999
# 5   05ARE      5  ARE         1          6     0      0.3336          NaN
# 6   05ARE      5  ARE         1          7     0      0.3318    85.410004
# 7   05ARE      5  ARE         1          8     0     -0.4342    79.739998
# 8   05ARE      5  ARE         1          9     0      1.0425    82.410004
# 9   05ARE      5  ARE         1         10     0     -0.2433    58.070000
# 10  05ARE      5  ARE         1         11     0     -1.3721    26.620001
# 11  05ARE      5  ARE         1         12     0      0.2502    88.699997
# ...

# %%
PISA_df = pd.read_sas('PISA/SCH_QQQ_SAS/cy08msp_sch_qqq.sas7bdat')

# %%
PISA_df.sample(20)
# Out:
#           CNT  CNTRYID    CNTSCHID      CYC     NatCen   STRATUM    SUBNATIO  \
# 4569   b'TAP'    158.0  15800214.0  b'08MS'  b'015800'  b'TAP04'  b'1580000'
# 12826  b'MEX'    484.0  48400201.0  b'08MS'  b'048400'  b'MEX02'  b'4840000'
# 9708   b'ISR'    376.0  37600002.0  b'08MS'  b'037600'  b'ISR97'  b'3760000'
# 2845   b'BRA'     76.0   7600605.0  b'08MS'  b'007600'  b'BRA14'  b'0760000'
# 18665  b'SWE'    752.0  75200182.0  b'08MS'  b'075200'  b'SWE04'  b'7520000'
# 15934  b'ROU'    642.0  64200026.0  b'08MS'  b'064200'  b'ROU02'  b'6420000'
# 12873  b'MEX'    484.0  48400251.0  b'08MS'  b'048400'  b'MEX09'  b'4840000'
# 6734   b'FIN'    246.0  24600007.0  b'08MS'  b'024600'  b'FIN19'  b'2460000'
# 3896   b'CAN'    124.0  12400641.0  b'08MS'  b'012400'  b'CAN99'  b'1240000'
# 2065   b'BEL'     56.0   5600096.0  b'08MS'  b'005602'  b'BEL27'  b'0560000'
# 11127  b'KAZ'    398.0  39800327.0  b'08MS'  b'039800'  b'KAZ07'  b'3980000'
# ...

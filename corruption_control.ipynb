# %%
import pandas as pd

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
corrup = pd.read_excel('data/Percentage_corruption_control.xlsx')

# %%
# Import get_dataframe from sql_functions.py
from sql_functions import get_dataframe
#from sql_functions import get_engine

# %%
schema = 'capstone_health_education'
sql_1 = f'SELECT * FROM {schema}.syb_public_expenditure_on_education_continents'
syb_expend_edu = get_dataframe(sql_1)

# %%
syb_expend_edu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 11 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   country                                                          978 non-null    object
#  1   continent                                                        978 non-null    object
#  2   continent_region                                                 978 non-null    object
#  3   year                                                             978 non-null    object
#  4   all_staff_compensation_as_perc_of_total_expenditure_in_public_i  437 non-null    object
#  5   basic_access_to_computers_by_level_of_education_lower_secondary  248 non-null    object
#  6   basic_access_to_computers_by_level_of_education_primary          324 non-null    object
#  7   basic_access_to_computers_by_level_of_education_upper_secondary  250 non-null    object
#  8   capital_expenditure_as_perc_of_total_expenditure_in_public_inst  448 non-null    object
#  9   current_expenditure_other_than_staff_compensation_as_perc_of_to  430 non-null    object
#  10  public_expenditure_on_education_perc_of_gdp                      883 non-null    object
# dtypes: object(11)
# memory usage: 84.2+ KB

# %%
schema = 'capstone_health_education'
sql_2 = f'SELECT * FROM {schema}.syb_expenditure_on_health_continents'
syb_expend_health = get_dataframe(sql_2)

# %%
syb_expend_health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 6 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   country                                                          1133 non-null   object
#  1   continent                                                        1133 non-null   object
#  2   continent_region                                                 1133 non-null   object
#  3   year                                                             1133 non-null   object
#  4   current_health_expenditure_perc_of_gdp                           1129 non-null   object
#  5   domestic_general_government_health_expenditure_perc_of_total_go  1133 non-null   object
# dtypes: object(6)
# memory usage: 53.2+ KB

# %%
corrup.head()
# Out:
#           Unnamed: 0 Unnamed: 1    2010.0  2010.0.1 2010.0.2   2010.0.3  \
# 0  Country/Territory       Code  Estimate    StdErr   NumSrc       Rank
# 1              Aruba        ABW  1.121296  0.292717      2.0  83.333336
# 2            Andorra        ADO  1.301773  0.430663      1.0  88.095238
# 3        Afghanistan        AFG -1.645391  0.195123      9.0   0.952381
# 4             Angola        AGO -1.332475  0.160683     12.0   3.809524
#
#     2010.0.4   2010.0.5    2011.0  2011.0.1  ... 2021.0.2   2021.0.3  \
# 0      Lower      Upper  Estimate    StdErr  ...   NumSrc       Rank
# 1  72.380951  91.904762  1.102947  0.296301  ...      2.0  78.571426
# 2  71.904762  94.761902  1.272298   0.41817  ...      1.0  88.571426
# 3        0.0   3.809524 -1.600471  0.195457  ...      8.0  12.380953
# 4   0.952381  14.285714 -1.367469  0.158418  ...     10.0  29.047619
#
#     2021.0.4   2021.0.5    2022.0  2022.0.1 2022.0.2   2022.0.3   2022.0.4  \
# 0      Lower      Upper  Estimate    StdErr   NumSrc       Rank      Lower
# 1  62.857143  89.047623  0.756785   0.31725      2.0  77.830185  60.849056
# 2       70.0  96.666664  1.270204  0.463415      1.0  88.679245  68.396225
# 3   4.761905  20.952381 -1.183776   0.17332      8.0  12.264151   4.716981
# 4  19.523809  40.476189 -0.601941  0.160003     10.0  30.660378  21.226416
#
#     2022.0.5
# 0      Upper
# 1  88.679245
# 2  97.169815
# 3  20.283018
# 4  43.396225
#
# [5 rows x 80 columns]

# %%
corrup.shape
# Out:
# (215, 80)

# %%
syb_expend_edu.head()
# Out:
#        country continent continent_region  year  \
# 0  Afghanistan      Asia             Asia  2010
# 1  Afghanistan      Asia             Asia  2015
# 2  Afghanistan      Asia             Asia  2019
# 3  Afghanistan      Asia             Asia  2020
# 4      Albania    Europe     South Europe  2005
#
#   all_staff_compensation_as_perc_of_total_expenditure_in_public_i  \
# 0                                               72.4
# 1                                               71.4
# 2                                               None
# 3                                               None
# 4                                               None
#
#   basic_access_to_computers_by_level_of_education_lower_secondary  \
# 0                                               None
# 1                                               None
# 2                                                 10
# 3                                               None
# 4                                               None
#
#   basic_access_to_computers_by_level_of_education_primary  \
# 0                                               None
# 1                                               None
# 2                                                9.0
# 3                                               None
# 4                                               None
#
#   basic_access_to_computers_by_level_of_education_upper_secondary  \
# 0                                               None
# 1                                               None
# 2                                                 23
# 3                                               None
# 4                                               None
#
#   capital_expenditure_as_perc_of_total_expenditure_in_public_inst  \
# 0                                               18.3
# 1                                               19.6
# 2                                               None
# 3                                               None
# 4                                               None
#
#   current_expenditure_other_than_staff_compensation_as_perc_of_to  \
# 0                                                9.3
# 1                                                9.0
# 2                                               None
# 3                                               None
# 4                                               None
#
#   public_expenditure_on_education_perc_of_gdp
# 0                                         3.5
# 1                                         3.3
# 2                                         3.2
# 3                                         2.9
# 4                                         3.3

# %%
syb_expend_health.head()
# Out:
#        country continent continent_region  year  \
# 0  Afghanistan      Asia             Asia  2005
# 1  Afghanistan      Asia             Asia  2010
# 2  Afghanistan      Asia             Asia  2015
# 3  Afghanistan      Asia             Asia  2018
# 4  Afghanistan      Asia             Asia  2019
#
#   current_health_expenditure_perc_of_gdp  \
# 0                                    9.9
# 1                                    8.6
# 2                                   10.1
# 3                                   14.2
# 4                                   14.8
#
#   domestic_general_government_health_expenditure_perc_of_total_go
# 0                                                3.4
# 1                                                2.3
# 2                                                2.0
# 3                                                1.9
# 4                                                1.8
